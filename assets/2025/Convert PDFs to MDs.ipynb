# %% [markdown]
# ## Pre-work
#
# Install pymupdf4llm with `pip install pymupdf4llm`

# %%
import pymupdf4llm, pathlib
from IPython.display import display, Markdown

# %% [markdown]
# ## Converting the PDFs to Markdown
#
# Buggy code!
#
# This takes an optional argument `pathstr` used to generate Markdown files per folder if necessary. Ideally, you don't need to use this, but I did need to because my first version of the code missed NCR ballots entirely.
#
# This took like 6 hours (2:00 PM - 8:00 PM) to process 1681 files on my beefy computer, so dedicate some good time the next time you run this.
#
# Could I have used a faster converter/library? Yes, but the last time I used a faster one (for the 2022 elections), I got some issues with my parser. PymuPDF4LLM preserves the tables which we will use to better split the data.

# %%
def convert_to_markdown(pathstr: str = "./pdf/"):
    root_path = pathlib.Path(pathstr)
    for pdf_file in root_path.glob("*.pdf"):
            md_text = pymupdf4llm.to_markdown(pdf_file)
            pathlib.Path(f"./md/{root_path.name}.{pdf_file.stem}.md").write_bytes(md_text.encode())
    for region in root_path.iterdir():
        if region.is_dir():
            for pdf_file in region.glob("*.pdf"):
                md_text = pymupdf4llm.to_markdown(pdf_file)
                pathlib.Path(f"./md/{region.name}.{pdf_file.stem}.md").write_bytes(md_text.encode())
            for province in region.iterdir():
                if province.is_dir():
                    for pdf_file in province.glob("*.pdf"):
                        md_text = pymupdf4llm.to_markdown(pdf_file)
                        pathlib.Path(f"./md/{region.name}.{province.name}.{pdf_file.stem}.md").write_bytes(md_text.encode())

# %%
convert_to_markdown("./pdf/NCR/")
# Out:
# Processing pdf\NCR\CITY_OF_CALOOCAN_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_CALOOCAN_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_CALOOCAN_3RD_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_LAS_PIÑAS_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_LAS_PIÑAS_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MAKATI_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MAKATI_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MALABON_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MALABON_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANDALUYONG_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANDALUYONG_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_3RD_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_4TH_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_5TH_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MANILA_6TH_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MARIKINA_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MARIKINA_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MUNTINLUPA_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_MUNTINLUPA_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_NAVOTAS_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_NAVOTAS_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_PARAÑAQUE_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_PARAÑAQUE_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_PASIG_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_PASIG_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_SAN_JUAN_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_SAN_JUAN_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_TAGUIG_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_TAGUIG_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_VALENZUELA_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\CITY_OF_VALENZUELA_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\PASAY_CITY_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\PASAY_CITY_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\PATEROS_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\PATEROS_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_1ST_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_2ND_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_3RD_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_4TH_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_5TH_DIST.pdf...
# ]========================================] (2/2)
# Processing pdf\NCR\QUEZON_CITY_6TH_DIST.pdf...
# ]========================================] (2/2)

# %%
from IPython.display import display, Markdown
display(Markdown(md_text))
# Out:
# **MAY 12, 2025 NATIONAL, LOCAL AND BARMM**
# **PARLIAMENTARY ELECTIONS**
# **PASONG TAMO, QUEZON CITY, NATIONAL CAPITAL**
# **REGION - SECOND DISTRICT**
#
# INSTRUCTIONS FOR VOTING
#
# 1. Mark the inside of the circle beside the name of the desired candidate.
#
# 2. Only use the Marking pen provided to mark the circles.
#
# 3. Do not mark more circles than what is intended.
#
#
# Clustered Precinct ID: 74041567
#
# Precincts in Cluster:
# 3304A, 3304B, 3304C, 3304D,
#
# 3304E, 3304F
#
#
# Signature of chairman
#
# |1. CO-PILAR, MARIVIC (NUP)||||
# |MAYOR / Vote for 1 (Bumoto ng hindi hihigit sa 1)||||
# |1. BELMONTE, JOY (SBP)|3. JOTA, ROLANDO (IND)|5. VELASCO, DIOSDADO (IND)||
# |2. CABALO, JONATHAN (IND)|4. NAVAT, NOLI (IND)|||
# |VICE-MAYOR / Vote for 1 (Bumoto ng hindi hihigit sa 1)||||
# |1. FAELANGCO, JUNE (IND)|2. INGLES, INVENTOR (IND)|3. SOTTO, GIAN (SBP)|4. VILLARTA, DANTE (IND)|
# |MEMBER, SANGGUNIANG PANLUNGSOD / Vote for 6 (Bumoto ng hindi hihigit sa 6)||||
# |1. BERNARDO, VIC (SBP)|4. GOMEZ, OSCAR JR. (IND)|7. MEDINA, COCOY (SBP)||
# |2. FRANCISCO, HELEN (IND)|5. JUAN, DOC ELLIE (SBP)|8. PILAR, BANJO (SBP)||
# |3. GENEROSO, SOTTO VITO (SBP)|6. MATIAS, KRISTINE DONNY (SBP)|9. SALUDES, LOUIE (IND)||
#
#
# FOR PARTY LIST CANDIDATES, CHECK THE BACK OF THIS BALLOT
# Para sa mga kandidato ng Party List, tingnan ang likod ng balotang ito
#
# Page 1 of 2
#
#
# CGEG@COM CGEG@COM CGEG@COM CGEG@COM CGEG@C0M
#
#
# -----
#
# **MAY 12, 2025 NATIONAL, LOCAL AND BARMM**
# **PARLIAMENTARY ELECTIONS**
# **PASONG TAMO, QUEZON CITY, NATIONAL CAPITAL**
# **REGION - SECOND DISTRICT**
#
# PARAAN NG PAGBOTO
#
# 1. Markahan ang loob ng bilog sa tabi ng nais ibotong kandidato.
#
# 2. Gamitin lamang ang marking pen na ibinigay para sa pagmarka ng mga bilog.
#
# 3. Huwag markahan ng hihigit sa dapat.
#
#
# Clustered Precinct ID: 74041567
#
# Precincts in Cluster:
# 3304A, 3304B, 3304C, 3304D,
#
# 3304E, 3304F
#
# |PARTY LIST / Vote for 1 (Bumoto ng hindi hihigit sa 1)|Col2|Col3|Col4|
# |---|---|---|---|
# |1 4PS|40 BABAE AKO|80 BOSES PARTY-LIST|119 COOP-NATCCO|
# |2 PPP|41 ARISE|81 ARANGKADA PILIPINO|120 KABAYAN|
# |3 FPJ PANDAY BAYANIHAN|42 MAGDALO|82 AANGAT TAYO|121 1MUNTI|
# |4 KABATAAN|43 APEC|83 OFW|122 PINOY WORKERS|
# |5 DUTERTE YOUTH|44 MAGBUBUKID|84 BIDA KATAGUMPAY|123 API PARTY|
# |6 ML|45 SSS-GSIS PENSYONADO|85 KAMANGGAGAWA|124 AKO BISAYA|
# |7 PBBM|46 GABRIELA|86 BFF|125 KAMALAYAN|
# |8 P3PWD|47 TINGOG|87 BUNYOG|126 AKO TANOD|
# |9 MURANG KURYENTE|48 APAT-DAPAT|88 AGRI|127 PROBINSYANO AKO|
# |10 BICOL SARO|49 AHON MAHIRAP|89 SENIOR CITIZENS|128 KABABAIHAN|
# |11 IPATUPAD|50 UGB|90 4K|129 RAM|
# |12 PATROL|51 AKBAYAN|91 PBP|130 ALONA|
# |13 JUAN PINOY|52 AGIMAT|92 ONE COOP|131 AKO BICOL|
# |14 ARTE|53 PHILRECA|93 CIBAC|132 GP (GALING SA PUSO)|
# |15 WIFI|54 KAPUSO PM|94 BH - BAGONG HENERASYON|133 KAUNLAD PINOY|
# |16 MAAGAP|55 ILOCANO DEFENDERS|95 1AGILA|134 ABP|
# |17 UNITED SENIOR CITIZENS|56 1-RIDER PARTY-LIST|96 EDUAKSYON|135 CWS|
# |18 EPANAW SAMBAYANAN|57 TICTOK|97 ANG TINIG NG SENIORS|136 LPGMA|
# |19 AKO PADAYON|59 BAYAN MUNA|98 BG PARTY-LIST|137 A TEACHER|
# |20 TUCP|60 ANG PROBINSIYANO|99 PINOY AKO|138 SWERTE|
# |21 ACT TEACHERS|61 BANAT|100 H.E.L.P. PILIPINAS|139 GABAY|
# |22 1PACMAN|62 SBP|101 HEALTH WORKERS|140 MALASAKIT@BAYANIHAN|
# |23 TGP|63 BUHAY|102 PEOPLE'S CHAMP|141 AKAY NI SOL|
# |24 DUMPER PTDA|64 TULUNGAN TAYO|103 AA-KASOSYO PARTY|142 LUNAS|
# |25 ANAKALUSUGAN|65 SAGIP|104 SOLID NORTH PARTY|143 DIWA|
# |26 AKSYON DAPAT|66 BTS BAYANING TSUPER|105 ABAMIN|144 PINUNO|
# |27 BHW|67 VENDORS|106 TRABAHO|145 PAMILYA MUNA|
# |28 SULONG DIGNIDAD|68 ACT-CIS|107 ANGKASANGGA|146 BAGONG PILIPINAS|
# |29 BATANG QUIAPO|69 AKTIBONG KAAGAPAY|108 TODA AKSYON|147 HUGPONG FEDERAL|
# |30 PBA|70 ASENSO PINOY|109 TURISMO|148 TUPAD|
# |31 GILAS|71 SOLO PARENTS|110 ABONO|149 LAANG KAWAL|
# |32 AKO ILOCANO AKO|72 ANG KOMADRONA|111 ASAP NA|150 PAMILYA KO|
# |33 PAMILYANG MAGSASAKA|73 PROMDI|112 LINGAP|151 BBM|
# |34 CLICK PARTY|74 PUSONG PINOY|113 UNITED FRONTLINERS|152 HEAL PH|
# |35 ABANTE BISDAK|75 KUSUG TAUSUG|114 KASAMBAHAY|153 ABANG LINGKOD|
# |36 MANILA TEACHERS|76 DAMAYANG FILIPINO|115 TUTOK TO WIN|154 MAGSASAKA|
# |37 PAMANA|77 MPBL|116 AKO OFW|155 MAHARLIKA|
# |38 NANAY|78 ANGAT|117 AGAP|156 USWAG ILONGGO|
# |39 KM NGAYON NA|79 KALINGA|118 1TAHANAN||
#
#
# -----

# %% [markdown]
# ## Getting the candidates for national posts
#
# There are special ballots for Local Absentee Voters and Overseas Voters which are not tied to any local posts. We use this as basis for the national candidates (and as a sanity check when we extract the local candidates next).

# %%
md_text = pymupdf4llm.to_markdown("./OV.pdf")
pathlib.Path(f"./OV.md").write_bytes(md_text.encode())
# Out:
# Processing ./OV.pdf...
# [                                        ] (0/2===================[====================                    ] (1/2===================[========================================] (2/2]
# 6747

# %% [markdown]
# I will now switch to Node.js as I prefer using this over Python to process the Markdown files.
